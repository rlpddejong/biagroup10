# %% [markdown]
# # Notebook Assignment 1
#
# Course: 8P361  &emsp;&emsp;  Group: 10
#
# Helgers, V.M.J. 	&emsp;&emsp; 1329332 <br>
# Jong, de R.L.P.D. 	&emsp; 1328328 <br>
# Korsten, T.		    &emsp;&emsp;&emsp;&emsp; 1340522 <br>
# Moharir, S. 		&emsp;&emsp;&emsp;&emsp; 1296256 <br>

# %% [markdown]
# ## IMPORTANT NOTE
#
# In order for this code to run, open-cv should be installed in the working environment. <br>
# To install open-cv type the following lines of code in the anaconda prompt:
#
#     conda activate **environment name**
#
#     pip install opencv-python

# %% [markdown]
# ## 1. Load images of category 0 (without metastases)

# %% [markdown]
# Important: To load images of category 0 the correct pathname of a folder that has these images has to be added below.

# %%
from Assignment1_Group10 import load_images_from_folder

# Folder path of category 0
folder_path = "C:/Users/20182054/OneDrive - TU Eindhoven/Bachelor/Jaar 3/Kwartiel 3/Project Imaging - BIA (8P361)/Data/train+val/train/0"

# Load images of category 0
load_images_from_folder(folder_path)

# %% [markdown]
# ## 2. Load images of category 1 (with metastases)

# %% [markdown]
# Important: To load images of category 1 the correct pathname of a folder that has these images has to be added below.

# %%
from Assignment1_Group10 import load_images_from_folder

# Folder path of category 1
folder_path = "C:/Users/20182054/OneDrive - TU Eindhoven/Bachelor/Jaar 3/Kwartiel 3/Project Imaging - BIA (8P361)/Data/train+val/train/1"

# Load images of category 1
load_images_from_folder(folder_path)
