# %% [markdown]
# # Optimization of the number of epochs
# Course: 8P361  &emsp;&emsp;  Group: 10
#
# Helgers, V.M.J. 	&emsp;&emsp; 1329332 <br>
# Jong, de R.L.P.D.	&emsp;  1328328 <br>
# Korsten, T.		    &emsp;&emsp;&emsp;&emsp; 1340522 <br>
# Moharir, S. 		&emsp;&emsp;&emsp;&emsp; 1296256 <br>

# %% [markdown]
# ## Important notes
#
# 1. Note that all functions needed to execute this notebook can be found in the Optimization_Epoch.py file.
#
# 2. If one wants to run this notebook it is important to add the right path to the image data within the function 'get_pcam_generators' which is called below.

# %% [markdown]
# ## What the notebook does
# This notebook is created to see what the optimal number of epochs is for the model. It has been chosen to set the number of epochs to 15 and check when the accuracy and loss curves converge to a certain value.

# %% [markdown]
# ### 1. First, import the relevant functions.

# %%
from Optimization_Epoch import get_pcam_generators, get_model, train_model, plot_acc_loss

# %% [markdown]
# ### 2 Get the model

# %%
train_gen, val_gen = get_pcam_generators('data')
# Out:
# Found 144000 images belonging to 2 classes.
# Found 16000 images belonging to 2 classes.

# %%
model = get_model()

# %%
train_model(model,train_gen,val_gen,'model')
# Out:
# /home/8p361-lecturer/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/15
# 1125/1125 [==============================] - 150s 127ms/step - loss: 0.4896 - accuracy: 0.7607 - val_loss: 0.3415 - val_accuracy: 0.8504
#
# Epoch 00001: val_loss improved from inf to 0.34154, saving model to model_weights.hdf5
# Epoch 2/15
# 1125/1125 [==============================] - 136s 121ms/step - loss: 0.3311 - accuracy: 0.8572 - val_loss: 0.2916 - val_accuracy: 0.8704
#
# Epoch 00002: val_loss improved from 0.34154 to 0.29157, saving model to model_weights.hdf5
# Epoch 3/15
# 1125/1125 [==============================] - 137s 121ms/step - loss: 0.2579 - accuracy: 0.8931 - val_loss: 0.2085 - val_accuracy: 0.9184
#
# ...

# %% [markdown]
# ### 3 Loss and accuracy curves

# %% [markdown]
# #### 3.1 Training and validation loss

# %%
run1_train_loss = [0.5055, 0.3310, 0.2586, 0.2160, 0.1959, 0.1710, 0.1585, 0.1380, 0.1281, 0.1177, 0.1049, 0.0962, 0.0877, 0.0779, 0.0721]
run2_train_loss = [0.5184, 0.3333, 0.2602, 0.2170, 0.1950, 0.1763, 0.1554, 0.1415, 0.1323, 0.1209, 0.1105, 0.0988, 0.0911, 0.0830, 0.0788]
run3_train_loss = [0.4896, 0.3311, 0.2579, 0.2112, 0.1888, 0.1708, 0.1507, 0.1384, 0.1264, 0.1167, 0.1014, 0.0925, 0.0841, 0.0756, 0.0687]

run1_val_loss   = [0.3394, 0.2604, 0.2133, 0.2440, 0.1992, 0.1901, 0.1895, 0.1656, 0.1544, 0.1669, 0.1555, 0.1646, 0.1632, 0.1801, 0.1699]
run2_val_loss   = [0.3287, 0.2584, 0.2357, 0.2036, 0.2131, 0.1733, 0.1662, 0.1661, 0.1753, 0.1648, 0.1870, 0.1742, 0.1753, 0.2136, 0.2380]
run3_val_loss   = [0.3415, 0.2916, 0.2085, 0.2110, 0.1986, 0.1767, 0.1748, 0.1809, 0.2053, 0.1669, 0.1613, 0.1757, 0.1823, 0.1755, 0.1975]

plot_acc_loss(run1_train_loss, run2_train_loss, run3_train_loss, run1_val_loss, run2_val_loss, run3_val_loss, case='loss')

# %% [markdown]
# #### 3.1 Training and validation accuracy

# %%
run1_train_acc = [0.7482, 0.8572, 0.8952, 0.9152, 0.9237, 0.9346, 0.9400, 0.9492, 0.9530, 0.9571, 0.9627, 0.9649, 0.9678, 0.9715, 0.9735]
run2_train_acc = [0.7352, 0.8559, 0.8941, 0.9142, 0.9243, 0.9334, 0.9418, 0.9475, 0.9511, 0.9565, 0.9592, 0.9643, 0.9668, 0.9698, 0.9716]
run3_train_acc = [0.7607, 0.8572, 0.8931, 0.9172, 0.9272, 0.9347, 0.9434, 0.9478, 0.9530, 0.9567, 0.9620, 0.9658, 0.9683, 0.9724, 0.9745]

run1_val_acc   = [0.8564, 0.8924, 0.9171, 0.9025, 0.9222, 0.9276, 0.9298, 0.9368, 0.9425, 0.9386, 0.9429, 0.9412, 0.9416, 0.9431, 0.9449]
run2_val_acc   = [0.8591, 0.8940, 0.9036, 0.9187, 0.9166, 0.9345, 0.9354, 0.9374, 0.9336, 0.9397, 0.9344, 0.9375, 0.9379, 0.9245, 0.9176]
run3_val_acc   = [0.8504, 0.8704, 0.9184, 0.9170, 0.9253, 0.9320, 0.9346, 0.9318, 0.9299, 0.9443, 0.9423, 0.9420, 0.9404, 0.9392, 0.9331]

plot_acc_loss(run1_train_acc, run2_train_acc, run3_train_acc, run1_val_acc, run2_val_acc, run3_val_acc, case='acc')
